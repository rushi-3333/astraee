# %%
import pandas as pd

# %%
food_data = pd.read_csv(r'Dataset\food_comparison_dataset_swiggy_zomato.csv')
ride_data = pd.read_csv(r'Dataset\hyderabad_ride_comparison_dataset.csv')
medicine_data = pd.read_csv(r'Dataset\medicine_comparison_dataset_netmeds_pharmeasy_apollo.csv')
shopping_data = pd.read_csv(r'Dataset\shopping_comparison_dataset_amazon_flipkart_ajio.csv')
user_interaction_data = pd.read_csv(r'Dataset\user_interaction_rl_dataset.csv')

# %%
food_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   food_id             10000 non-null  str
#  1   platform            10000 non-null  str
#  2   restaurant_name     10000 non-null  str
#  3   restaurant_id       10000 non-null  str
#  4   food_item           10000 non-null  str
#  5   category            10000 non-null  str
#  6   food_price          10000 non-null  float64
#  7   delivery_fee        10000 non-null  float64
#  8   packaging_fee       10000 non-null  float64
#  9   tax_amount          10000 non-null  float64
#  10  final_price         10000 non-null  float64
#  11  delivery_time_min   10000 non-null  int64
#  12  restaurant_rating   10000 non-null  float64
#  13  review_count        10000 non-null  int64
#  14  available_coupon    10000 non-null  int64
#  15  coupon_discount     10000 non-null  float64
# ...

# %%
ride_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ride_id                 10000 non-null  str
#  1   platform                10000 non-null  str
#  2   pickup_location         10000 non-null  str
#  3   destination             10000 non-null  str
#  4   distance_km             10000 non-null  float64
#  5   estimated_duration_min  10000 non-null  int64
#  6   vehicle_type            10000 non-null  str
#  7   fare_price              10000 non-null  float64
#  8   base_fare               10000 non-null  float64
#  9   surge_multiplier        10000 non-null  float64
#  10  estimated_arrival_min   10000 non-null  int64
#  11  driver_rating           10000 non-null  float64
#  12  available_coupon        10000 non-null  int64
#  13  coupon_discount         10000 non-null  float64
# ...

# %%
medicine_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   medicine_id            10000 non-null  str
#  1   platform               10000 non-null  str
#  2   medicine_name          10000 non-null  str
#  3   manufacturer           10000 non-null  str
#  4   composition            10000 non-null  str
#  5   pack_size              10000 non-null  str
#  6   mrp                    10000 non-null  float64
#  7   selling_price          10000 non-null  float64
#  8   discount_percentage    10000 non-null  float64
#  9   coupon_discount        10000 non-null  float64
#  10  cashback               10000 non-null  float64
#  11  final_price            10000 non-null  float64
#  12  availability           10000 non-null  str
#  13  delivery_time_hours    10000 non-null  float64
#  14  prescription_required  10000 non-null  str
# ...

# %%
shopping_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           15000 non-null  str
#  1   platform             15000 non-null  str
#  2   product_name         15000 non-null  str
#  3   brand                15000 non-null  str
#  4   category             15000 non-null  str
#  5   subcategory          15000 non-null  str
#  6   original_price       15000 non-null  float64
#  7   selling_price        15000 non-null  float64
#  8   discount_percentage  15000 non-null  float64
#  9   cashback             15000 non-null  float64
#  10  coupon_discount      15000 non-null  float64
#  11  final_price          15000 non-null  float64
#  12  delivery_days        15000 non-null  int64
#  13  seller_name          15000 non-null  str
#  14  seller_rating        15000 non-null  float64
# ...

# %%
user_interaction_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   interaction_id               12000 non-null  str
#  1   user_id                      12000 non-null  str
#  2   search_category              12000 non-null  str
#  3   recommended_platform         12000 non-null  str
#  4   chosen_platform              12000 non-null  str
#  5   recommended_price            12000 non-null  float64
#  6   chosen_price                 12000 non-null  float64
#  7   delivery_time                12000 non-null  float64
#  8   coupon_used                  12000 non-null  str
#  9   cashback_used                12000 non-null  str
#  10  user_clicked_recommendation  12000 non-null  str
#  11  booking_completed            12000 non-null  str
#  12  savings_amount               12000 non-null  float64
# ...
